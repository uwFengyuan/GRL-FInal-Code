# %%
import os
import torch
import torch.nn as nn
import numpy as np
import time
import torch.nn.functional as F
# torch_geometric only used to load the Cora dataset
from torch_geometric.datasets import Planetoid
from torch_geometric.loader import DataLoader
import torch_geometric.utils as U
import torch.optim as optim
import matplotlib.pyplot as plt
import torch_geometric.nn as geom_nn
from models import GATModule, ModifiedGATModule, GNNModule, MLPModule
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# %matplotlib inline

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

datasetCora = Planetoid("/tmp/Cora", name="Cora")
datasetCiteSeer = Planetoid("/tmp/CiteSeer", name="CiteSeer")
datasetPubMed = Planetoid("/tmp/PubMed", name="PubMed")
datasetlist = [datasetCora, datasetCiteSeer, datasetPubMed]

# %%
class NodeClassification(nn.Module):

    def __init__(self, num_features, hidden_dim, gcn_layers, mlp_layers, num_classes, gnn_act_fn, mlp_act_fn, control_gate, dropout):
      super().__init__()

      self.GNN = None
      self.MLP = None
      
      # GNNModule()
      if control_gate == 'GATMLP':
        self.GNN = GATModule(num_features, hidden_dim, hidden_dim, gcn_layers, gnn_act_fn, dropout)
        self.MLP = MLPModule(hidden_dim, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)
      elif control_gate == 'ModifiedGATMLP':
        self.GNN = ModifiedGATModule(num_features, hidden_dim, hidden_dim, gcn_layers, gnn_act_fn, dropout)
        self.MLP = MLPModule(hidden_dim, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)
      elif control_gate == 'GNNMLP':
        self.GNN = GNNModule(num_features, hidden_dim, hidden_dim, gcn_layers, gnn_act_fn, dropout)
        self.MLP = MLPModule(hidden_dim, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)
      elif control_gate == 'ModifiedGAT':
        self.GNN = ModifiedGATModule(num_features, hidden_dim, num_classes, gcn_layers, gnn_act_fn, dropout)
      elif control_gate == 'GAT':
        self.GNN = GATModule(num_features, hidden_dim, num_classes, gcn_layers, gnn_act_fn, dropout)
      elif control_gate == 'GNN':
        self.GNN = GNNModule(num_features, hidden_dim, num_classes, gcn_layers, gnn_act_fn, dropout)
      elif control_gate == 'MLP':
        self.MLP = MLPModule(num_features, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)

    def forward(self, x, adj_matrix):
      if self.GNN is not None:
        x = self.GNN(x, adj_matrix)

      if self.MLP is not None:
        x = self.MLP(x)

      return x
  
    # Used to reset the weights of the network when training multiple times with
    # different hyperparameters
    def reset_parameters(self):
        def _reset_module_parameters(module):
            for layer in module.children():
                if hasattr(layer, 'reset_parameters'):
                    layer.reset_parameters()
                elif hasattr(layer, 'children'):
                    for child_layer in layer.children():
                        _reset_module_parameters(child_layer)

        _reset_module_parameters(self)

# %%
def train(model, data, adj_matrix, params):
    model.reset_parameters()
    model.train()
    # 定义优化器，通过优化器选择更新的方式
    opt =  optim.Adam(model.parameters(), lr = params["learning_rate"])
    # 定义损失函数，通过损失函数计算梯度
    loss_module = nn.CrossEntropyLoss()

    losses = []
    accuracies = []
    test_accuracies = []
    best_test = 0
    early_stopping = 0
    best_epoch = 0
    
    for e in range(0, params["num_epochs"]):
        # 清空之前的梯度
        opt.zero_grad()
        
        # 得到训练和测试向量
        train_d = data.train_mask
        test_d = data.test_mask

        train_pred = model(data.x, adj_matrix) # 分类预测
        # loss(input, target)
        loss = loss_module(train_pred[train_d], data.y[train_d])
        train_accuracy = (train_pred[train_d].argmax(dim=-1) == data.y[train_d]).sum().float() / train_d.sum()
        test_accuracy = (train_pred[test_d].argmax(dim=1) == data.y[test_d]).sum().float() / test_d.sum()

        #if e % 8 == 0:
        #    print(f"train_loss: {loss}, train_accuracy: {train_accuracy}, and test_accuracy: {test_accuracy}")
        losses.append(loss)
        accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)
        if test_accuracy <= best_test:
            early_stopping += 1
        if best_test < test_accuracy:
            best_test = test_accuracy
            best_epoch = e
            early_stopping = 0
        if early_stopping == 10:
            print(f"Best test accuracy is {best_test} with {best_epoch} epochs")
            break

        # 计算梯度
        loss.backward()
        # 更新参数
        opt.step()
    
    return losses, accuracies, test_accuracies, best_test, best_epoch

# %%
for model_name in ['MLP', 'GNN', 'GAT', 'ModifiedGAT']:
    print(f"THIS MODEL IS: {model_name}")
    with open('output.txt', 'w') as f:
        print(f"This model is: {model_name}", file = f)
    for dataset in datasetlist:
        num_nodes = dataset.data.num_nodes
        num_edges = dataset.data.num_edges // 2
        num_features = dataset.num_node_features
        num_classes = dataset.num_classes

        data = dataset[0].to(device)
        adj_matrix = U.to_dense_adj(data.edge_index).squeeze(0)

        params = {
            "hidden_features": 64,
            "num_gcn_layers": 2,
            "num_mlp_layers": 2,
            "learning_rate": 0.005,
            "weight_decay": 0,
            "num_epochs": 300,
            "dropout": 0.2,
        }

        model = NodeClassification(num_features,
                                    params["hidden_features"],
                                    params["num_gcn_layers"],
                                    params["num_mlp_layers"],
                                    num_classes,
                                    gnn_act_fn=nn.ReLU(inplace = True),
                                    mlp_act_fn=nn.ReLU(inplace = True),
                                    control_gate=model_name,
                                    dropout=params['dropout']
        ).to(device)
        timelength_list = []
        best_test_list = []
        best_epoch_list = []
        for i in range(10):
            start = time.time()
            train_losses, train_accuracies, test_accuracies, best_test, best_epoch = train(model, data, adj_matrix, params)
            end = time.time()
            timelength = end - start

            timelength_list.append(timelength)
            best_test_list.append(best_test)
            best_epoch_list.append(best_epoch)

            #plt.plot([_ for _ in train_accuracies], label = "train_accuracy")
            #plt.plot([_ for _ in test_accuracies], label = "test_accuracy")
            #plt.legend()
            #plt.show()
        print(dataset.name + ": ")
        print(f"Mean best test accuracy: {np.mean(best_test_list)}; SD: {np.std(best_test_list)}")
        print(f"Mean runtime: {np.mean(timelength_list)}; Mean epoches: {np.mean(best_epoch_list)}")
        with open('output.txt', 'w') as f:
            print(dataset.name + ": ", file = f)
            print(f"Mean best test accuracy: {np.mean(best_test_list)}; SD: {np.std(best_test_list)}", file = f)
            print(f"Mean runtime: {np.mean(timelength_list)}; Mean epoches: {np.mean(best_epoch_list)}", file = f)
# Out:
# THIS MODEL IS: MLP
# Best test accuracy is 0.5249999761581421 with 12 epochs
# Best test accuracy is 0.5180000066757202 with 1 epochs
# Best test accuracy is 0.5109999775886536 with 1 epochs
# Best test accuracy is 0.4959999918937683 with 1 epochs
# Best test accuracy is 0.48100000619888306 with 13 epochs
# Best test accuracy is 0.48100000619888306 with 1 epochs
# Best test accuracy is 0.47999998927116394 with 13 epochs
# Best test accuracy is 0.4869999885559082 with 11 epochs
# Best test accuracy is 0.4880000054836273 with 0 epochs
# Best test accuracy is 0.5049999952316284 with 7 epochs
# Cora:
# Mean best test accuracy: 0.49720001220703125; SD: 0.015708591789007187
# Mean runtime: 0.20306849479675293; Mean epoches: 6.0
# Best test accuracy is 0.5040000081062317 with 13 epochs
# Best test accuracy is 0.4950000047683716 with 1 epochs
# Best test accuracy is 0.4830000102519989 with 14 epochs
# Best test accuracy is 0.48500001430511475 with 6 epochs
# Best test accuracy is 0.4729999899864197 with 7 epochs
# Best test accuracy is 0.4690000116825104 with 8 epochs
# Best test accuracy is 0.4880000054836273 with 4 epochs
# Best test accuracy is 0.4860000014305115 with 12 epochs
# Best test accuracy is 0.47699999809265137 with 7 epochs
# Best test accuracy is 0.48399999737739563 with 9 epochs
# CiteSeer:
# Mean best test accuracy: 0.4843999743461609; SD: 0.009676778689026833
# Mean runtime: 0.6372554779052735; Mean epoches: 8.1
# Best test accuracy is 0.6949999928474426 with 6 epochs
# Best test accuracy is 0.6980000138282776 with 7 epochs
# Best test accuracy is 0.6949999928474426 with 7 epochs
# Best test accuracy is 0.6909999847412109 with 7 epochs
# Best test accuracy is 0.6880000233650208 with 4 epochs
# Best test accuracy is 0.6990000009536743 with 7 epochs
# Best test accuracy is 0.6919999718666077 with 6 epochs
# Best test accuracy is 0.6819999814033508 with 0 epochs
# Best test accuracy is 0.6880000233650208 with 7 epochs
# Best test accuracy is 0.6930000185966492 with 8 epochs
# PubMed:
# Mean best test accuracy: 0.6920999884605408; SD: 0.004867239389568567
# Mean runtime: 0.2830753564834595; Mean epoches: 5.9
# THIS MODEL IS: GNN
# Best test accuracy is 0.7730000019073486 with 6 epochs
# Best test accuracy is 0.7289999723434448 with 10 epochs
# Best test accuracy is 0.7450000047683716 with 14 epochs
# Best test accuracy is 0.75 with 36 epochs
# Best test accuracy is 0.753000020980835 with 7 epochs
# Best test accuracy is 0.7540000081062317 with 20 epochs
# Best test accuracy is 0.7829999923706055 with 15 epochs
# Best test accuracy is 0.7480000257492065 with 4 epochs
# Best test accuracy is 0.7730000019073486 with 18 epochs
# Best test accuracy is 0.7540000081062317 with 3 epochs
# Cora:
# Mean best test accuracy: 0.7561999559402466; SD: 0.015078463591635227
# Mean runtime: 0.5813634872436524; Mean epoches: 13.3
# Best test accuracy is 0.6269999742507935 with 8 epochs
# Best test accuracy is 0.6150000095367432 with 17 epochs
# Best test accuracy is 0.6039999723434448 with 13 epochs
# Best test accuracy is 0.6150000095367432 with 13 epochs
# Best test accuracy is 0.6100000143051147 with 15 epochs
# Best test accuracy is 0.609000027179718 with 13 epochs
# Best test accuracy is 0.6380000114440918 with 11 epochs
# Best test accuracy is 0.6230000257492065 with 9 epochs
# Best test accuracy is 0.6320000290870667 with 6 epochs
# Best test accuracy is 0.6209999918937683 with 8 epochs
# CiteSeer:
# Mean best test accuracy: 0.6193999648094177; SD: 0.01024890597909689
# Mean runtime: 1.0236054182052612; Mean epoches: 11.3
# Best test accuracy is 0.7770000100135803 with 34 epochs
# Best test accuracy is 0.7829999923706055 with 37 epochs
# Best test accuracy is 0.7670000195503235 with 21 epochs
# Best test accuracy is 0.7630000114440918 with 16 epochs
# Best test accuracy is 0.7760000228881836 with 29 epochs
# Best test accuracy is 0.7760000228881836 with 34 epochs
# Best test accuracy is 0.7799999713897705 with 39 epochs
# Best test accuracy is 0.7710000276565552 with 22 epochs
# Best test accuracy is 0.7699999809265137 with 23 epochs
# Best test accuracy is 0.7549999952316284 with 14 epochs
# PubMed:
# Mean best test accuracy: 0.7717999815940857; SD: 0.008009991608560085
# Mean runtime: 4.906471538543701; Mean epoches: 26.9
# THIS MODEL IS: GAT
# Best test accuracy is 0.7799999713897705 with 17 epochs
# Best test accuracy is 0.7900000214576721 with 17 epochs
# Best test accuracy is 0.7799999713897705 with 6 epochs
# Best test accuracy is 0.7950000166893005 with 21 epochs
# Best test accuracy is 0.7770000100135803 with 24 epochs
# Best test accuracy is 0.7730000019073486 with 5 epochs
# Best test accuracy is 0.7889999747276306 with 20 epochs
# Best test accuracy is 0.7960000038146973 with 5 epochs
# Best test accuracy is 0.777999997138977 with 8 epochs
# Best test accuracy is 0.7829999923706055 with 21 epochs
# Cora:
# Mean best test accuracy: 0.7840999364852905; SD: 0.007515988312661648
# Mean runtime: 7.501246166229248; Mean epoches: 14.4
# Best test accuracy is 0.6520000100135803 with 6 epochs
# Best test accuracy is 0.6480000019073486 with 8 epochs
# Best test accuracy is 0.6610000133514404 with 4 epochs
# Best test accuracy is 0.652999997138977 with 8 epochs
# Best test accuracy is 0.6489999890327454 with 12 epochs
# Best test accuracy is 0.6620000004768372 with 7 epochs
# Best test accuracy is 0.6480000019073486 with 7 epochs
# Best test accuracy is 0.6489999890327454 with 5 epochs
# Best test accuracy is 0.6470000147819519 with 7 epochs
# Best test accuracy is 0.652999997138977 with 8 epochs
# CiteSeer:
# Mean best test accuracy: 0.652199923992157; SD: 0.005075432825833559
# Mean runtime: 8.763768887519836; Mean epoches: 7.2
# Best test accuracy is 0.7099999785423279 with 4 epochs
# Best test accuracy is 0.7070000171661377 with 8 epochs
# Best test accuracy is 0.7080000042915344 with 11 epochs
# Best test accuracy is 0.75 with 62 epochs
# Best test accuracy is 0.699999988079071 with 8 epochs
# Best test accuracy is 0.7129999995231628 with 7 epochs
# Best test accuracy is 0.7089999914169312 with 11 epochs
# Best test accuracy is 0.7039999961853027 with 10 epochs
# Best test accuracy is 0.7089999914169312 with 8 epochs
# Best test accuracy is 0.703000009059906 with 4 epochs
# PubMed:
# Mean best test accuracy: 0.7113000154495239; SD: 0.013386934995651245
# Mean runtime: 468.51095061302186; Mean epoches: 13.3
# THIS MODEL IS: ModifiedGAT
# Best test accuracy is 0.7730000019073486 with 16 epochs
# Best test accuracy is 0.7940000295639038 with 4 epochs
# Best test accuracy is 0.7749999761581421 with 2 epochs
# Best test accuracy is 0.7639999985694885 with 8 epochs
# Best test accuracy is 0.7799999713897705 with 17 epochs
# Best test accuracy is 0.777999997138977 with 6 epochs
# Best test accuracy is 0.7789999842643738 with 10 epochs
# Best test accuracy is 0.7710000276565552 with 10 epochs
# Best test accuracy is 0.7649999856948853 with 3 epochs
# Best test accuracy is 0.7570000290870667 with 6 epochs
# Cora:
# Mean best test accuracy: 0.7735999822616577; SD: 0.009779569692909718
# Mean runtime: 5.846811580657959; Mean epoches: 8.2
# Best test accuracy is 0.652999997138977 with 3 epochs
# Best test accuracy is 0.6349999904632568 with 3 epochs
# Best test accuracy is 0.6439999938011169 with 4 epochs
# Best test accuracy is 0.6370000243186951 with 3 epochs
# Best test accuracy is 0.6420000195503235 with 6 epochs
# Best test accuracy is 0.6299999952316284 with 10 epochs
# Best test accuracy is 0.6470000147819519 with 4 epochs
# Best test accuracy is 0.6420000195503235 with 4 epochs
# Best test accuracy is 0.628000020980835 with 5 epochs
# Best test accuracy is 0.656000018119812 with 5 epochs
# CiteSeer:
# Mean best test accuracy: 0.6414000391960144; SD: 0.008697126060724258
# Mean runtime: 7.344598340988159; Mean epoches: 4.7
# Best test accuracy is 0.6990000009536743 with 6 epochs
# Best test accuracy is 0.7599999904632568 with 73 epochs
# Best test accuracy is 0.7549999952316284 with 47 epochs
# Best test accuracy is 0.7490000128746033 with 54 epochs
# Best test accuracy is 0.75 with 51 epochs
# Best test accuracy is 0.7049999833106995 with 12 epochs
# Best test accuracy is 0.7059999704360962 with 10 epochs
# Best test accuracy is 0.75 with 48 epochs
# Best test accuracy is 0.7200000286102295 with 20 epochs
# Best test accuracy is 0.7419999837875366 with 51 epochs
# PubMed:
# Mean best test accuracy: 0.7336000204086304; SD: 0.02227644808590412
# Mean runtime: 1231.2126331329346; Mean epoches: 37.2
